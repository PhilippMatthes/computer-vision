# %% [markdown]
# # The Task
#
# 1. Install OpenCV with debug libs on your system.
# 2. Take two photos of a static (not changing) object,
# about 3m away from two view points, with about
# 10cm horizontal distance.
# 3. Measure the overall brightness of the two images and adjust
# it to the mean value of the two images.
# 4. Create a mixed image and put the red channel from the
# (adjusted) left image and the green and blue channel from
# the right image into said mixed image.
# Do this by (i) looping over all the pixels,
# (ii) by using opencv functions – compare the runtime!
# 5. View the mixed image with red-cyan glasses ;-)

# %%
import cv2
from matplotlib import pyplot as plt

# %%
def read_image_grayscale(filename):
    return cv2.imread(filename, 0)


def read_image(filename):
    return cv2.imread(filename)


def show_image_greyscale(image):
    plt.imshow(image, cmap='gray')
    plt.show()


def save_image(filename, image):
    cv2.imwrite(filename, image)


def edge_detection(image, thr_low=0, thr_high=255):
    return cv2.Canny(image,thr_low, thr_high)


def bilateral_filter(image):
    return cv2.bilateralFilter(image, 9, 75, 75)

# %%
img = read_image("images/apb.jpg")
for i in [x * 10 for x in range(0, 25)]:
    blur = bilateral_filter(img)
    edges = edge_detection(blur, thr_low=i, thr_high=i)
    print("Edge detection on image with threshold: {} (high and low)".format(i))
    show_image_greyscale(edges)
# Out:
# Edge detection on image with threshold: 0 (high and low)
# Edge detection on image with threshold: 10 (high and low)
# Edge detection on image with threshold: 20 (high and low)
# Edge detection on image with threshold: 30 (high and low)
# Edge detection on image with threshold: 40 (high and low)
# Edge detection on image with threshold: 50 (high and low)
# Edge detection on image with threshold: 60 (high and low)
# Edge detection on image with threshold: 70 (high and low)
# Edge detection on image with threshold: 80 (high and low)
# Edge detection on image with threshold: 90 (high and low)
# Edge detection on image with threshold: 100 (high and low)
# Edge detection on image with threshold: 110 (high and low)
# Edge detection on image with threshold: 120 (high and low)
# Edge detection on image with threshold: 130 (high and low)
# Edge detection on image with threshold: 140 (high and low)
# Edge detection on image with threshold: 150 (high and low)
# Edge detection on image with threshold: 160 (high and low)
# Edge detection on image with threshold: 170 (high and low)
# Edge detection on image with threshold: 180 (high and low)
# Edge detection on image with threshold: 190 (high and low)
# Edge detection on image with threshold: 200 (high and low)
# Edge detection on image with threshold: 210 (high and low)
# Edge detection on image with threshold: 220 (high and low)
# Edge detection on image with threshold: 230 (high and low)
# Edge detection on image with threshold: 240 (high and low)
