# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # The Task
#
# The Task is to look for the most prominent Edge direction in the given images.
#
# # The Solution
#
# - Import the given images
# - Convert the images to greyscale
# - Apply the sobel filter to the images, rotated from 0 to 179 Degrees
# - Sum the brightness of all pixels in the calculated images
# - Show the accumulated brightness in a histogram

# %%
def read_image_grayscale(filename):
    return cv.imread(filename, 0)

# %%
def apply_sobel(degrees, image):
    image = np.uint8(np.clip(image, 0, 255))
    dx = np.abs(np.sin(np.deg2rad(degrees)))
    dy = np.abs(np.cos(np.deg2rad(degrees)))
    x_sobel = cv.Sobel(image, cv.CV_64F, 1, 0, ksize=5) * dx
    y_sobel = cv.Sobel(image, cv.CV_64F, 0, 1, ksize=5) * dy
    return np.abs(x_sobel + y_sobel)

# %%
def show_image_greyscale(image):
    plt.imshow(image, cmap='gray')
    plt.show()


def save_image(filename, image):
    cv.imwrite(filename, image)

# %%
def show_edge_histogram(image):
    degrees = range(0, 179)
    images = [apply_sobel(d, image) for d in degrees]
    brightness_values = [np.sum(image) for image in images]
    
    max_element_index = brightness_values.index(max(brightness_values))
    print("The angle most present in this image is {} Degrees.".format(max_element_index))
    
    plt.bar(degrees, brightness_values)
    plt.show()

# %%
image = read_image_grayscale("images/lines1.png")
show_image_greyscale(image)
for degree in [d * 30 for d in range(0, 6)]:
    print("Sobel filter for {} degrees".format(degree))
    show_image_greyscale(apply_sobel(degree, image))
show_edge_histogram(image)
# Out:
# Sobel filter for 0 degrees
# Sobel filter for 30 degrees
# Sobel filter for 60 degrees
# Sobel filter for 90 degrees
# Sobel filter for 120 degrees
# Sobel filter for 150 degrees
# The angle most present in this image is 13 Degrees.

# %%
image = read_image_grayscale("images/lines2.png")
show_image_greyscale(image)
for degree in [d * 30 for d in range(0, 6)]:
    print("Sobel filter for {} degrees".format(degree))
    show_image_greyscale(apply_sobel(degree, image))
show_edge_histogram(image)
# Out:
# Sobel filter for 0 degrees
# Sobel filter for 30 degrees
# Sobel filter for 60 degrees
# Sobel filter for 90 degrees
# Sobel filter for 120 degrees
# Sobel filter for 150 degrees
# The angle most present in this image is 13 Degrees.

# %%
image = read_image_grayscale("images/keyb7.jpg")
show_image_greyscale(image)
for degree in [d * 30 for d in range(0, 6)]:
    print("Sobel filter for {} degrees".format(degree))
    show_image_greyscale(apply_sobel(degree, image))
show_edge_histogram(image)
# Out:
# Sobel filter for 0 degrees
# Sobel filter for 30 degrees
# Sobel filter for 60 degrees
# Sobel filter for 90 degrees
# Sobel filter for 120 degrees
# Sobel filter for 150 degrees
# The angle most present in this image is 0 Degrees.
